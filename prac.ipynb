# %%
# !pip install spacy

# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Using cached spacy-3.8.13-cp314-cp314-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.15-cp314-cp314-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.13-cp314-cp314-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.13-cp314-cp314-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Using cached thinc-8.3.13-cp314-cp314-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Using cached srsly-2.5.3-cp314-cp314-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Using cached weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Using cached confection-1.3.2-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from spacy) (2.32.5)
# Collecting pydantic<3.0.0,>=2.0.0 (from spacy)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: jinja2 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from spacy) (3.1.6)
# Collecting setuptools (from spacy)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\homepc\appdata\roaming\python\python314\site-packages (from spacy) (25.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached pydantic_core-2.41.5-cp314-cp314-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Using cached blis-1.3.3-cp314-cp314-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\users\homepc\appdata\roaming\python\python314\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Collecting httpx>=0.24.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpcore==1.* (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\homepc\appdata\roaming\python\python314\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy)
#   Downloading wrapt-2.1.2-cp314-cp314-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\homepc\appdata\local\programs\python\python314\lib\site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.13-cp314-cp314-win_amd64.whl (14.4 MB)
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.4 MB 4.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.3/14.4 MB 4.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.9/14.4 MB 4.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.7/14.4 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 4.7/14.4 MB 4.2 MB/s eta 0:00:03
#    --------------- ------------------------ 5.5/14.4 MB 4.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.0/14.4 MB 4.0 MB/s eta 0:00:03
#    ------------------ --------------------- 6.8/14.4 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 7.3/14.4 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.1/14.4 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 8.7/14.4 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 9.2/14.4 MB 3.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.2/14.4 MB 3.7 MB/s eta 0:00:02
#    ------------------------------ --------- 11.0/14.4 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 11.8/14.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.3/14.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 13.1/14.4 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 13.9/14.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 14.4/14.4 MB 3.6 MB/s  0:00:04
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.2-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp314-cp314-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp314-cp314-win_amd64.whl (26 kB)
# Downloading preshed-3.0.13-cp314-cp314-win_amd64.whl (125 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp314-cp314-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.0 MB 5.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.9 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp314-cp314-win_amd64.whl (656 kB)
#    ---------------------------------------- 0.0/656.5 kB ? eta -:--:--
#    ---------------------------------------- 656.5/656.5 kB 3.2 MB/s  0:00:00
# Downloading thinc-8.3.13-cp314-cp314-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.1 MB/s  0:00:00
# Downloading blis-1.3.3-cp314-cp314-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 10.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.6/6.3 MB 3.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.3 MB 3.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.6/6.3 MB 3.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.3 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 3.3 MB/s  0:00:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.5.1-py3-none-any.whl (64 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ------------------------------- -------- 0.8/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.2 MB/s  0:00:00
# Downloading wrapt-2.1.2-cp314-cp314-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, wasabi, typing-inspection, tqdm, spacy-loggers, spacy-legacy, shellingham, setuptools, pydantic-core, murmurhash, mdurl, h11, cymem, confection, cloudpathlib, catalogue, blis, anyio, annotated-types, annotated-doc, srsly, smart-open, pydantic, preshed, markdown-it-py, httpcore, thinc, rich, httpx, typer, weasel, spacy
#
#    ----------------------------------------  0/32 [wrapt]
#    - --------------------------------------  1/32 [wasabi]
#    -- -------------------------------------  2/32 [typing-inspection]
#    --- ------------------------------------  3/32 [tqdm]
#    --- ------------------------------------  3/32 [tqdm]
#    --- ------------------------------------  3/32 [tqdm]
#    ----- ----------------------------------  4/32 [spacy-loggers]
#    ----- ----------------------------------  4/32 [spacy-loggers]
#    ------ ---------------------------------  5/32 [spacy-legacy]
#    ------- --------------------------------  6/32 [shellingham]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    -------- -------------------------------  7/32 [setuptools]
#    ---------- -----------------------------  8/32 [pydantic-core]
#    ------------ --------------------------- 10/32 [mdurl]
#    ------------- -------------------------- 11/32 [h11]
#    --------------- ------------------------ 12/32 [cymem]
#    ---------------- ----------------------- 13/32 [confection]
#    ----------------- ---------------------- 14/32 [cloudpathlib]
#    ----------------- ---------------------- 14/32 [cloudpathlib]
#    ----------------- ---------------------- 14/32 [cloudpathlib]
#    ------------------ --------------------- 15/32 [catalogue]
#    -------------------- ------------------- 16/32 [blis]
#    --------------------- ------------------ 17/32 [anyio]
#    --------------------- ------------------ 17/32 [anyio]
#    --------------------- ------------------ 17/32 [anyio]
#    --------------------- ------------------ 17/32 [anyio]
#    ---------------------- ----------------- 18/32 [annotated-types]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    ------------------------- -------------- 20/32 [srsly]
#    -------------------------- ------------- 21/32 [smart-open]
#    -------------------------- ------------- 21/32 [smart-open]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    --------------------------- ------------ 22/32 [pydantic]
#    ---------------------------- ----------- 23/32 [preshed]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [markdown-it-py]
#    ------------------------------- -------- 25/32 [httpcore]
#    ------------------------------- -------- 25/32 [httpcore]
#    ------------------------------- -------- 25/32 [httpcore]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    -------------------------------- ------- 26/32 [thinc]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    --------------------------------- ------ 27/32 [rich]
#    ----------------------------------- ---- 28/32 [httpx]
#    ----------------------------------- ---- 28/32 [httpx]
#    ----------------------------------- ---- 28/32 [httpx]
#    ----------------------------------- ---- 28/32 [httpx]
#    ------------------------------------ --- 29/32 [typer]
#    ------------------------------------ --- 29/32 [typer]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#
kB/s eta 0:00:08
#      ---------------------------- ---------- 9.4/12.8 MB 449.3 kB/s eta 0:00:08
#      ----------------------------- --------- 9.7/12.8 MB 452.4 kB/s eta 0:00:07
#      ----------------------------- --------- 9.7/12.8 MB 452.4 kB/s eta 0:00:07
#      ----------------------------- -------- 10.0/12.8 MB 456.3 kB/s eta 0:00:07
#      ------------------------------ ------- 10.2/12.8 MB 460.6 kB/s eta 0:00:06
#      ------------------------------ ------- 10.2/12.8 MB 460.6 kB/s eta 0:00:06
#      ------------------------------- ------ 10.5/12.8 MB 465.6 kB/s eta 0:00:05
#      ------------------------------- ------ 10.5/12.8 MB 465.6 kB/s eta 0:00:05
#      ------------------------------- ------ 10.7/12.8 MB 469.9 kB/s eta 0:00:05
#      -------------------------------- ----- 11.0/12.8 MB 474.9 kB/s eta 0:00:04
#      --------------------------------- ---- 11.3/12.8 MB 480.6 kB/s eta 0:00:04
#      --------------------------------- ---- 11.3/12.8 MB 480.6 kB/s eta 0:00:04
#      ---------------------------------- --- 11.5/12.8 MB 485.3 kB/s eta 0:00:03
#      ----------------------------------- -- 11.8/12.8 MB 491.6 kB/s eta 0:00:03
#      ----------------------------------- -- 12.1/12.8 MB 498.1 kB/s eta 0:00:02
#      ------------------------------------ - 12.3/12.8 MB 504.9 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 512.1 kB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 516.9 kB/s  0:00:25
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# Inspect spaCy's built-in stop word list 
print(f'spaCy has {len(nlp.Defaults.stop_words)} English stop words')
print('Sample:', sorted(list(nlp.Defaults.stop_words))[:12])

# Remove stop words from a sentence 
sentence = 'The quick brown fox jumps over the lazy dog near the river'
doc = nlp(sentence)

# Keep only words that are: alphabetic, not a stop word
content_words = [token.text for token in doc
                 if not token.is_stop and token.is_alpha]

print(f'Original ({len(doc)} tokens): {[t.text for t in doc]}')
print(f'Filtered ({len(content_words)} tokens): {content_words}')

# Customise the stop list - add domain-specific word to the stop list
nlp.vocab['data'].is_stop = True

# preserve negation words — removing 'not' flips sentiment!
# spaCy keeps 'not', 'no', 'never' etc. in the stop list by default.
# Be careful not to remove them for sentiment tasks.
safe_check = ['not', 'no', 'never', 'nor', 'neither']
for w in safe_check:
    print(f"  '{w}' is_stop = {nlp.vocab[w].is_stop}")
# Out:
# spaCy has 326 English stop words
# Sample: ["'d", "'ll", "'m", "'re", "'s", "'ve", 'a', 'about', 'above', 'across', 'after', 'afterwards']
# Original (12 tokens): ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'near', 'the', 'river']
# Filtered (8 tokens): ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'near', 'river']
#   'not' is_stop = True
#   'no' is_stop = True
#   'never' is_stop = True
#   'nor' is_stop = True
#   'neither' is_stop = True

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# Lemmatization in action 
sentence = 'The geese were running faster than the mice had ever studied'
doc = nlp(sentence)

print(f'{'Token':<14} {'Lemma':<14} {'POS'}')
print('-' * 40)
for token in doc:
    if not token.is_punct and not token.is_space:
        print(f'{token.text:<14} {token.lemma_:<14} {token.pos_}')
# Out:
# Token          Lemma          POS
# ----------------------------------------
# The            the            DET
# geese          goose          NOUN
# were           be             AUX
# running        run            VERB
# faster         fast           ADV
# than           than           SCONJ
# the            the            DET
# mice           mouse          NOUN
# had            have           AUX
# ever           ever           ADV
# studied        study          VERB

# %%
import spacy
from collections import defaultdict

nlp = spacy.load('en_core_web_sm')

text = (
    'Apple Inc. CEO Tim Cook announced on Tuesday that the company '
    'will invest $10 billion in manufacturing across the United States. '
    'Apple shares rose 3.5 percent on the Nasdaq.'
)
doc = nlp(text)

# Print every entity with its type 
print(f"{'Entity':<28} {'Label':<12} {'Description'}")
print('-' * 65)
for ent in doc.ents:
    desc = spacy.explain(ent.label_) or ''
    print(f'{ent.text:<28} {ent.label_:<12} {desc}')

# Group by type 
groups = defaultdict(set)
for ent in doc.ents:
    groups[ent.label_].add(ent.text)

print('\nGrouped by entity type:')
for label, entities in sorted(groups.items()):
    print(f'  {label:<12}: {", ".join(sorted(entities))}')

# Add custom entity patterns 
# The base model might miss domain-specific entities.
# Use EntityRuler to add your own patterns before the NER component.
from spacy.pipeline import EntityRuler
ruler = nlp.add_pipe('entity_ruler', before='ner')
ruler.add_patterns([
    {'label': 'AI_MODEL', 'pattern': [{'TEXT': {'IN': ['BERT','GPT-4','T5','LLaMA']}}]},
    {'label': 'COUNTY',   'pattern': [{'LOWER': 'nairobi'}]},
])
doc2 = nlp('BERT and GPT-4 are widely used in Nairobi for AI research.')
for ent in doc2.ents:
    print(f'  Custom: {ent.text} -> {ent.label_}')
# Out:
# Entity                       Label        Description
# -----------------------------------------------------------------
# Apple Inc.                   ORG          Companies, agencies, institutions, etc.
# Tim Cook                     PERSON       People, including fictional
# Tuesday                      DATE         Absolute or relative dates or periods
# $10 billion                  MONEY        Monetary values, including unit
# the United States            GPE          Countries, cities, states
# Apple                        ORG          Companies, agencies, institutions, etc.
# 3.5 percent                  PERCENT      Percentage, including "%"
# Nasdaq                       ORG          Companies, agencies, institutions, etc.
#
# Grouped by entity type:
#   DATE        : Tuesday
#   GPE         : the United States
#   MONEY       : $10 billion
#   ORG         : Apple, Apple Inc., Nasdaq
#   PERCENT     : 3.5 percent
#   PERSON      : Tim Cook
#   Custom: BERT -> AI_MODEL
#   Custom: GPT-4 -> AI_MODEL
#   Custom: Nairobi -> COUNTY
#   Custom: AI -> GPE

# %%
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

nlp = spacy.load('en_core_web_sm')

# Custom tokenizer: use spaCy's lemmas as tokens 
# This combines BoW with spaCy's linguistic processing.
# We lemmatize and remove stop words before vectorizing.
def spacy_tokenizer(text: str) -> list[str]:
    doc = nlp(text.lower())
    return [token.lemma_ for token in doc
            if not token.is_stop and not token.is_punct
            and token.is_alpha and len(token.text) > 2]

corpus = [
    'The cat sat on the mat',
    'The dog sat on the log',
    'The cat and the dog are friends',
]

# Use spaCy tokenizer inside sklearn's CountVectorizer
vectorizer = CountVectorizer(tokenizer=spacy_tokenizer)
X = vectorizer.fit_transform(corpus)

df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
df.index = [f'Doc {i+1}' for i in range(len(corpus))]
print(df)
# Out:
#        cat  dog  friend  log  mat  sit
# Doc 1    1    0       0    0    1    1
# Doc 2    0    1       0    1    0    1
# Doc 3    1    1       1    0    0    0
# c:\Users\HomePC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
