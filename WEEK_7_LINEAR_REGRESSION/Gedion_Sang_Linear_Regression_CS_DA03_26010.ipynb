# %% [markdown]
# ***Title: Linear Regression Assignment***
#
# ***Name: Gedion Sang***
#
# ***ID: CS-DA03-26010***
#
# ***Date: 13/03/2026***

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Introduction
#
# Exploring the datasets, train testing the model and visualizing the results
#
# - Exploring the datasets
#
# - Preparing and splitting data for training and testing
#
# - Building a simple linear regression model
#
# - Evaluating the model using key metrics
#
# - Visualizing predictions and regression lines

# %% [markdown]
# ## Importing Libraries

# %%
#Import the necessary libraries and dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uploading the Datasets

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5508bd8f-94c9-448a-909c-f7b2f37f0943" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5508bd8f-94c9-448a-909c-f7b2f37f0943">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
homeprices=pd.read_csv('homeprices.csv')
homeprices_m=pd.read_csv('homeprices-m.csv')
areas=pd.read_csv('areas.csv')

# %% [markdown]
# ### Exploring the Dataset

# %%
print('\nFirst 5 rows:')
print(areas.head(5))
print('\nFirst 5 rows:')
print(homeprices_m.head(5))
print('\nFirst 5 rows:')
print(homeprices.head(5))

# %%
print('Shape:',areas.shape)

print('\nInfo:')
print(areas.info())

# %%
print('Shape:',homeprices.shape)
print('\nInfo:')
print(homeprices.info())

# %%
print('Shape:',homeprices_m.shape)
print('\nInfo:')
print(homeprices_m.info())

# %%
plt.figure(figsize=(8, 5))
plt.scatter(homeprices['area'], homeprices['price'], color='blue')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Home Prices')
plt.show()

# %% [markdown]
# ## Preparing Data for Split

# %%
#importing dependency
from sklearn.model_selection import train_test_split
x=homeprices[['area']]
y=homeprices['price']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %% [markdown]
# ## Create a Simple Model

# %%
print("Coefficient (slope):", regressor.coef_[0])
print("Intercept:", regressor.intercept_)

# %% [markdown]
# ## Visualizing Prediction Set

# %%
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color='blue')
plt.plot(x, regressor.predict(x), color='red')
plt.xlabel('Area')
plt.ylabel('Prices')
plt.title('Simple Linear Regression')
plt.show()

# %% [markdown]
# ## Visualizing Testing Set

# %%
plt.figure(figsize=(8, 5))
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.title('Simple Linear Regression(Testing Set)')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Visualizing Training Set

# %%
plt.figure(figsize=(8, 5))
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.title('Simple Linear Regression(Training Set)')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Evaluating the Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = regressor.predict(x)

MSE = mean_squared_error(y, y_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y, y_pred)

print("Mean Squared Error:", MSE)
print("Root Mean Squared Error:", RMSE)
print("R-squared:", R2)

# %% [markdown]
# ## Conclusion
# The Simple Linear Regression model successfully demonstrated how house prices can be predicted based on area.
# The workflow covered all essential stages of a machine learning project including data exploration, visualization,
# model training, evaluation, and prediction. The results show that linear regression is an effective method for
# predicting housing prices when a strong linear relationship exists between variables.
